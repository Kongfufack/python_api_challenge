# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 632

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url =  "http://api.openweathermap.org/data/2.5/weather?"


# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | tuktoyaktuk
# Processing Record 2 of Set 1 | husavik
# Processing Record 3 of Set 1 | biak
# Processing Record 4 of Set 1 | puerto ayora
# Processing Record 5 of Set 1 | mandalgovi
# Processing Record 6 of Set 1 | sorong
# Processing Record 7 of Set 1 | belyy yar
# Processing Record 8 of Set 1 | sao filipe
# Processing Record 9 of Set 1 | abu dhabi
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 12 of Set 1 | nouadhibou
# Processing Record 13 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 14 of Set 1 | shenzhen
# Processing Record 15 of Set 1 | madera
# Processing Record 16 of Set 1 | mar del plata
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | hermanus
# Processing Record 19 of Set 1 | jamestown
# Processing Record 20 of Set 1 | ushuaia
# Processing Record 21 of Set 1 | atuona
# Processing Record 22 of Set 1 | mouila
# Processing Record 23 of Set 1 | pisco
# Processing Record 24 of Set 1 | wairoa
# Processing Record 25 of Set 1 | pangody
# Processing Record 26 of Set 1 | lavrentiya
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | tiznit
# Processing Record 29 of Set 1 | mouzouras
# Processing Record 30 of Set 1 | hanford
# Processing Record 31 of Set 1 | carnarvon
# Processing Record 32 of Set 1 | sergeyevka
# Processing Record 33 of Set 1 | ornskoldsvik
# Processing Record 34 of Set 1 | vila velha
# Processing Record 35 of Set 1 | rongcheng
# Processing Record 36 of Set 1 | vaini
# Processing Record 37 of Set 1 | pindobacu
# Processing Record 38 of Set 1 | kruisfontein
# Processing Record 39 of Set 1 | punta arenas
# Processing Record 40 of Set 1 | lagoa
# Processing Record 41 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | luderitz
# Processing Record 44 of Set 1 | bonnyville
# Processing Record 45 of Set 1 | mataura
# Processing Record 46 of Set 1 | bethel
# Processing Record 47 of Set 1 | tiksi
# Processing Record 48 of Set 1 | verkhoyansk
# Processing Record 49 of Set 1 | cape town
# Processing Record 50 of Set 1 | new norfolk
# Processing Record 0 of Set 2 | marzuq
# Processing Record 1 of Set 2 | klyuchi
# Processing Record 2 of Set 2 | aksay
# Processing Record 3 of Set 2 | phalaborwa
# Processing Record 4 of Set 2 | anderson
# Processing Record 5 of Set 2 | thunder bay
# Processing Record 6 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 7 of Set 2 | khatanga
# Processing Record 8 of Set 2 | dunedin
# Processing Record 9 of Set 2 | taoudenni
# Processing Record 10 of Set 2 | provideniya
# Processing Record 11 of Set 2 | thompson
# Processing Record 12 of Set 2 | atherton
# Processing Record 13 of Set 2 | lac du bonnet
# Processing Record 14 of Set 2 | le port
# Processing Record 15 of Set 2 | sant julia de loria
# Processing Record 16 of Set 2 | nikolskoye
# Processing Record 17 of Set 2 | vila franca do campo
# Processing Record 18 of Set 2 | shreveport
# Processing Record 19 of Set 2 | brigantine
# Processing Record 20 of Set 2 | rapid valley
# Processing Record 21 of Set 2 | beloha
# Processing Record 22 of Set 2 | albany
# Processing Record 23 of Set 2 | hovd
# Processing Record 24 of Set 2 | rio gallegos
# Processing Record 25 of Set 2 | kapaa
# Processing Record 26 of Set 2 | visnes
# Processing Record 27 of Set 2 | salgueiro
# Processing Record 28 of Set 2 | atasu
# Processing Record 29 of Set 2 | pevek
# Processing Record 30 of Set 2 | pakokku
# Processing Record 31 of Set 2 | champasak
# Processing Record 32 of Set 2 | kommunar
# Processing Record 33 of Set 2 | kahului
# Processing Record 34 of Set 2 | nemuro
# Processing Record 35 of Set 2 | sola
# Processing Record 36 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 37 of Set 2 | sitka
# Processing Record 38 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 39 of Set 2 | kazerun
# Processing Record 40 of Set 2 | fairview
# Processing Record 41 of Set 2 | shagonar
# Processing Record 42 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 2 | silver city
# Processing Record 44 of Set 2 | champerico
# Processing Record 45 of Set 2 | udachnyy
# Processing Record 46 of Set 2 | saldanha
# Processing Record 47 of Set 2 | kurumoch
# Processing Record 48 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 2 | xihe
# Processing Record 0 of Set 3 | upernavik
# Processing Record 1 of Set 3 | mahebourg
# Processing Record 2 of Set 3 | doha
# Processing Record 3 of Set 3 | shitanjing
# Processing Record 4 of Set 3 | mahibadhoo
# Processing Record 5 of Set 3 | yellowknife
# Processing Record 6 of Set 3 | klaksvik
# Processing Record 7 of Set 3 | wanning
# Processing Record 8 of Set 3 | san patricio
# Processing Record 9 of Set 3 | iqaluit
# Processing Record 10 of Set 3 | mayya
# Processing Record 11 of Set 3 | sangar
# Processing Record 12 of Set 3 | ancud
# Processing Record 13 of Set 3 | kentau
# Processing Record 14 of Set 3 | qaanaaq
# Processing Record 15 of Set 3 | acarau
# Processing Record 16 of Set 3 | torbay
# Processing Record 17 of Set 3 | okhotsk
# Processing Record 18 of Set 3 | bluff
# Processing Record 19 of Set 3 | nanortalik
# Processing Record 20 of Set 3 | xiongshi
# City not found. Skipping...
# Processing Record 21 of Set 3 | the valley
# Processing Record 22 of Set 3 | port macquarie
# Processing Record 23 of Set 3 | konevo
# Processing Record 24 of Set 3 | miri
# Processing Record 25 of Set 3 | naze
# Processing Record 26 of Set 3 | hilo
# Processing Record 27 of Set 3 | eydhafushi
# Processing Record 28 of Set 3 | kodiak
# Processing Record 29 of Set 3 | ayan
# Processing Record 30 of Set 3 | hualmay
# Processing Record 31 of Set 3 | avarua
# Processing Record 32 of Set 3 | severo-kurilsk
# Processing Record 33 of Set 3 | charlestown
# Processing Record 34 of Set 3 | saskylakh
# Processing Record 35 of Set 3 | xining
# Processing Record 36 of Set 3 | mercedes
# Processing Record 37 of Set 3 | la baule-escoublac
# Processing Record 38 of Set 3 | chintamani
# Processing Record 39 of Set 3 | bilibino
# Processing Record 40 of Set 3 | clyde river
# Processing Record 41 of Set 3 | kasongo-lunda
# Processing Record 42 of Set 3 | elbistan
# Processing Record 43 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 3 | port alfred
# Processing Record 45 of Set 3 | talas
# Processing Record 46 of Set 3 | moindou
# Processing Record 47 of Set 3 | ocampo
# Processing Record 48 of Set 3 | korla
# Processing Record 49 of Set 3 | buraydah
# Processing Record 0 of Set 4 | hobart
# Processing Record 1 of Set 4 | butaritari
# Processing Record 2 of Set 4 | lompoc
# Processing Record 3 of Set 4 | norman wells
# Processing Record 4 of Set 4 | mecca
# Processing Record 5 of Set 4 | alofi
# Processing Record 6 of Set 4 | minab
# Processing Record 7 of Set 4 | bengkulu
# Processing Record 8 of Set 4 | bawku
# Processing Record 9 of Set 4 | saint-georges
# Processing Record 10 of Set 4 | mengcheng
# Processing Record 11 of Set 4 | ivanivka
# Processing Record 12 of Set 4 | exeter
# Processing Record 13 of Set 4 | ambulu
# Processing Record 14 of Set 4 | longyearbyen
# Processing Record 15 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 4 | geraldton
# Processing Record 17 of Set 4 | erdenet
# Processing Record 18 of Set 4 | nabire
# Processing Record 19 of Set 4 | birao
# Processing Record 20 of Set 4 | east london
# Processing Record 21 of Set 4 | chumikan
# Processing Record 22 of Set 4 | jasper
# Processing Record 23 of Set 4 | odweyne
# Processing Record 24 of Set 4 | tasiilaq
# Processing Record 25 of Set 4 | tura
# Processing Record 26 of Set 4 | kirakira
# Processing Record 27 of Set 4 | anadyr
# Processing Record 28 of Set 4 | tshikapa
# Processing Record 29 of Set 4 | ust-koksa
# Processing Record 30 of Set 4 | te anau
# Processing Record 31 of Set 4 | nantucket
# Processing Record 32 of Set 4 | kathmandu
# Processing Record 33 of Set 4 | cabo san lucas
# Processing Record 34 of Set 4 | wulanhaote
# City not found. Skipping...
# Processing Record 35 of Set 4 | russell
# Processing Record 36 of Set 4 | dikson
# Processing Record 37 of Set 4 | iralaya
# Processing Record 38 of Set 4 | soyo
# Processing Record 39 of Set 4 | barrow
# Processing Record 40 of Set 4 | iskateley
# Processing Record 41 of Set 4 | duluth
# Processing Record 42 of Set 4 | codrington
# Processing Record 43 of Set 4 | tambura
# Processing Record 44 of Set 4 | warqla
# City not found. Skipping...
# Processing Record 45 of Set 4 | kokhma
# Processing Record 46 of Set 4 | port lincoln
# Processing Record 47 of Set 4 | la romana
# Processing Record 48 of Set 4 | ozuluama
# Processing Record 49 of Set 4 | georgetown
# Processing Record 0 of Set 5 | castro
# Processing Record 1 of Set 5 | victoria
# Processing Record 2 of Set 5 | souillac
# Processing Record 3 of Set 5 | walvis bay
# Processing Record 4 of Set 5 | kitob
# Processing Record 5 of Set 5 | palmer
# Processing Record 6 of Set 5 | riyadh
# Processing Record 7 of Set 5 | palauig
# Processing Record 8 of Set 5 | dingle
# Processing Record 9 of Set 5 | kahta
# Processing Record 10 of Set 5 | nyrob
# Processing Record 11 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 5 | bandarbeyla
# Processing Record 13 of Set 5 | nhulunbuy
# Processing Record 14 of Set 5 | aswan
# Processing Record 15 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 5 | hurghada
# Processing Record 17 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 18 of Set 5 | cidreira
# Processing Record 19 of Set 5 | los llanos de aridane
# Processing Record 20 of Set 5 | tautira
# Processing Record 21 of Set 5 | tuatapere
# Processing Record 22 of Set 5 | oktyabrskoye
# Processing Record 23 of Set 5 | tilichiki
# Processing Record 24 of Set 5 | leh
# Processing Record 25 of Set 5 | antofagasta
# Processing Record 26 of Set 5 | say
# Processing Record 27 of Set 5 | ixtapa
# Processing Record 28 of Set 5 | shingu
# Processing Record 29 of Set 5 | tak
# Processing Record 30 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 31 of Set 5 | ponta do sol
# Processing Record 32 of Set 5 | inuvik
# Processing Record 33 of Set 5 | kimbe
# Processing Record 34 of Set 5 | zeerust
# Processing Record 35 of Set 5 | praxedis guerrero
# Processing Record 36 of Set 5 | bay roberts
# Processing Record 37 of Set 5 | denau
# City not found. Skipping...
# Processing Record 38 of Set 5 | doka
# Processing Record 39 of Set 5 | faanui
# Processing Record 40 of Set 5 | katha
# City not found. Skipping...
# Processing Record 41 of Set 5 | taltal
# Processing Record 42 of Set 5 | praia da vitoria
# Processing Record 43 of Set 5 | idenao
# Processing Record 44 of Set 5 | kavaratti
# Processing Record 45 of Set 5 | oriximina
# Processing Record 46 of Set 5 | pangnirtung
# Processing Record 47 of Set 5 | cururupu
# Processing Record 48 of Set 5 | hamina
# Processing Record 49 of Set 5 | samarai
# Processing Record 0 of Set 6 | coahuayana
# Processing Record 1 of Set 6 | dolbeau
# City not found. Skipping...
# Processing Record 2 of Set 6 | rabo de peixe
# Processing Record 3 of Set 6 | puerto madryn
# Processing Record 4 of Set 6 | do gonbadan
# Processing Record 5 of Set 6 | henties bay
# Processing Record 6 of Set 6 | moorhead
# Processing Record 7 of Set 6 | galesong
# Processing Record 8 of Set 6 | avera
# Processing Record 9 of Set 6 | roma
# Processing Record 10 of Set 6 | bredasdorp
# Processing Record 11 of Set 6 | westport
# Processing Record 12 of Set 6 | guerrero negro
# Processing Record 13 of Set 6 | asau
# Processing Record 14 of Set 6 | kodinsk
# Processing Record 15 of Set 6 | saint-francois
# Processing Record 16 of Set 6 | iranshahr
# Processing Record 17 of Set 6 | deputatskiy
# Processing Record 18 of Set 6 | vangaindrano
# Processing Record 19 of Set 6 | lebu
# Processing Record 20 of Set 6 | grindavik
# Processing Record 21 of Set 6 | ilhabela
# Processing Record 22 of Set 6 | kaitangata
# Processing Record 23 of Set 6 | bhadrachalam
# Processing Record 24 of Set 6 | misawa
# Processing Record 25 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 6 | tomatlan
# Processing Record 27 of Set 6 | mount isa
# Processing Record 28 of Set 6 | wattegama
# Processing Record 29 of Set 6 | antalaha
# Processing Record 30 of Set 6 | yulara
# Processing Record 31 of Set 6 | zambezi
# Processing Record 32 of Set 6 | saint george
# Processing Record 33 of Set 6 | xuddur
# Processing Record 34 of Set 6 | verkhnyaya sinyachikha
# Processing Record 35 of Set 6 | oussouye
# Processing Record 36 of Set 6 | dao
# Processing Record 37 of Set 6 | klaeng
# Processing Record 38 of Set 6 | kavieng
# Processing Record 39 of Set 6 | mugumu
# Processing Record 40 of Set 6 | flinders
# Processing Record 41 of Set 6 | clearwater
# Processing Record 42 of Set 6 | srednekolymsk
# Processing Record 43 of Set 6 | rocha
# Processing Record 44 of Set 6 | murray bridge
# Processing Record 45 of Set 6 | artyom
# Processing Record 46 of Set 6 | novaya igirma
# Processing Record 47 of Set 6 | mehamn
# Processing Record 48 of Set 6 | mocambique
# City not found. Skipping...
# Processing Record 49 of Set 6 | paita
# Processing Record 0 of Set 7 | goderich
# Processing Record 1 of Set 7 | bambanglipuro
# Processing Record 2 of Set 7 | portobelo
# Processing Record 3 of Set 7 | dwarka
# Processing Record 4 of Set 7 | andenes
# Processing Record 5 of Set 7 | sept-iles
# Processing Record 6 of Set 7 | eskilstuna
# Processing Record 7 of Set 7 | tucumcari
# Processing Record 8 of Set 7 | alice springs
# Processing Record 9 of Set 7 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 7 | corinto
# Processing Record 11 of Set 7 | harper
# Processing Record 12 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 13 of Set 7 | arraial do cabo
# Processing Record 14 of Set 7 | chokurdakh
# Processing Record 15 of Set 7 | cherskiy
# Processing Record 16 of Set 7 | barabai
# Processing Record 17 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 18 of Set 7 | paamiut
# Processing Record 19 of Set 7 | puro
# Processing Record 20 of Set 7 | ribeira grande
# Processing Record 21 of Set 7 | punta de bombon
# Processing Record 22 of Set 7 | kandi
# Processing Record 23 of Set 7 | airai
# Processing Record 24 of Set 7 | bambous virieux
# Processing Record 25 of Set 7 | arman
# Processing Record 26 of Set 7 | tucuman
# Processing Record 27 of Set 7 | valdivia
# Processing Record 28 of Set 7 | port elizabeth
# Processing Record 29 of Set 7 | puerto ayacucho
# Processing Record 30 of Set 7 | pafos
# Processing Record 31 of Set 7 | igarka
# Processing Record 32 of Set 7 | kloulklubed
# Processing Record 33 of Set 7 | tanete
# Processing Record 34 of Set 7 | saint-pierre
# Processing Record 35 of Set 7 | maraba
# Processing Record 36 of Set 7 | faya
# Processing Record 37 of Set 7 | passo de camaragibe
# Processing Record 38 of Set 7 | cocobeach
# Processing Record 39 of Set 7 | mongo
# Processing Record 40 of Set 7 | san jose
# Processing Record 41 of Set 7 | bhachau
# Processing Record 42 of Set 7 | trincomalee
# Processing Record 43 of Set 7 | krasnoselkup
# Processing Record 44 of Set 7 | pictou
# Processing Record 45 of Set 7 | narsaq
# Processing Record 46 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 47 of Set 7 | vardo
# Processing Record 48 of Set 7 | port hedland
# Processing Record 49 of Set 7 | flin flon
# Processing Record 0 of Set 8 | yinchuan
# Processing Record 1 of Set 8 | wyndham
# Processing Record 2 of Set 8 | meulaboh
# Processing Record 3 of Set 8 | holetown
# Processing Record 4 of Set 8 | mizdah
# Processing Record 5 of Set 8 | ambilobe
# Processing Record 6 of Set 8 | cockburn town
# Processing Record 7 of Set 8 | san quintin
# Processing Record 8 of Set 8 | ballina
# Processing Record 9 of Set 8 | halifax
# Processing Record 10 of Set 8 | college
# Processing Record 11 of Set 8 | half moon bay
# Processing Record 12 of Set 8 | muisne
# Processing Record 13 of Set 8 | yar-sale
# Processing Record 14 of Set 8 | maceio
# Processing Record 15 of Set 8 | bobrovka
# Processing Record 16 of Set 8 | clonakilty
# Processing Record 17 of Set 8 | lolua
# City not found. Skipping...
# Processing Record 18 of Set 8 | hithadhoo
# Processing Record 19 of Set 8 | fuling
# Processing Record 20 of Set 8 | warrington
# Processing Record 21 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 22 of Set 8 | bathsheba
# Processing Record 23 of Set 8 | jalu
# Processing Record 24 of Set 8 | raton
# Processing Record 25 of Set 8 | phan thiet
# Processing Record 26 of Set 8 | ambalavao
# Processing Record 27 of Set 8 | semaria
# Processing Record 28 of Set 8 | morondava
# Processing Record 29 of Set 8 | kota tinggi
# Processing Record 30 of Set 8 | inverell
# Processing Record 31 of Set 8 | camopi
# Processing Record 32 of Set 8 | consett
# Processing Record 33 of Set 8 | saraipali
# Processing Record 34 of Set 8 | falkenberg
# Processing Record 35 of Set 8 | iskilip
# Processing Record 36 of Set 8 | xai-xai
# Processing Record 37 of Set 8 | elk city
# Processing Record 38 of Set 8 | sorvag
# City not found. Skipping...
# Processing Record 39 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 40 of Set 8 | sobolevo
# Processing Record 41 of Set 8 | jieshi
# Processing Record 42 of Set 8 | amol
# Processing Record 43 of Set 8 | elati
# Processing Record 44 of Set 8 | chitrakonda
# Processing Record 45 of Set 8 | itambe
# Processing Record 46 of Set 8 | margate
# Processing Record 47 of Set 8 | saint-philippe
# Processing Record 48 of Set 8 | aleksandrovka
# Processing Record 49 of Set 8 | kushima
# Processing Record 0 of Set 9 | ahipara
# Processing Record 1 of Set 9 | makakilo city
# Processing Record 2 of Set 9 | maloy
# Processing Record 3 of Set 9 | kasiri
# Processing Record 4 of Set 9 | araouane
# Processing Record 5 of Set 9 | olenino
# Processing Record 6 of Set 9 | betong
# Processing Record 7 of Set 9 | kuanshan
# City not found. Skipping...
# Processing Record 8 of Set 9 | zeya
# Processing Record 9 of Set 9 | olga
# Processing Record 10 of Set 9 | manbij
# Processing Record 11 of Set 9 | tabalosos
# Processing Record 12 of Set 9 | labutta
# City not found. Skipping...
# Processing Record 13 of Set 9 | cap estate
# Processing Record 14 of Set 9 | ulaangom
# Processing Record 15 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 16 of Set 9 | chaykovskiy
# Processing Record 17 of Set 9 | zhuanghe
# Processing Record 18 of Set 9 | vata de jos
# Processing Record 19 of Set 9 | guozhen
# Processing Record 20 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 9 | hastings
# Processing Record 22 of Set 9 | gigmoto
# Processing Record 23 of Set 9 | takoradi
# Processing Record 24 of Set 9 | portsmouth
# Processing Record 25 of Set 9 | mullaitivu
# City not found. Skipping...
# Processing Record 26 of Set 9 | camana
# Processing Record 27 of Set 9 | napanee
# Processing Record 28 of Set 9 | sur
# Processing Record 29 of Set 9 | ostrovnoy
# Processing Record 30 of Set 9 | morgan city
# Processing Record 31 of Set 9 | atka
# City not found. Skipping...
# Processing Record 32 of Set 9 | altay
# Processing Record 33 of Set 9 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 9 | vestmanna
# Processing Record 35 of Set 9 | wad madani
# Processing Record 36 of Set 9 | aykhal
# Processing Record 37 of Set 9 | lorengau
# Processing Record 38 of Set 9 | loreto
# Processing Record 39 of Set 9 | zaltan
# Processing Record 40 of Set 9 | akdagmadeni
# Processing Record 41 of Set 9 | vostok
# Processing Record 42 of Set 9 | horana
# Processing Record 43 of Set 9 | ukiah
# Processing Record 44 of Set 9 | manokwari
# Processing Record 45 of Set 9 | vaitape
# Processing Record 46 of Set 9 | dongsheng
# Processing Record 47 of Set 9 | pontes e lacerda
# Processing Record 48 of Set 9 | nuuk
# Processing Record 49 of Set 9 | katsuura
# Processing Record 0 of Set 10 | sabibah
# City not found. Skipping...
# Processing Record 1 of Set 10 | namibe
# Processing Record 2 of Set 10 | jahrom
# City not found. Skipping...
# Processing Record 3 of Set 10 | ambon
# Processing Record 4 of Set 10 | lasa
# Processing Record 5 of Set 10 | sokyryany
# Processing Record 6 of Set 10 | nizhniy kuranakh
# Processing Record 7 of Set 10 | amga
# Processing Record 8 of Set 10 | balod
# Processing Record 9 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 10 of Set 10 | tadine
# Processing Record 11 of Set 10 | mujiayingzi
# Processing Record 12 of Set 10 | pacific grove
# Processing Record 13 of Set 10 | ugoofaaru
# Processing Record 14 of Set 10 | ligayan
# Processing Record 15 of Set 10 | bahia blanca
# Processing Record 16 of Set 10 | leningradskiy
# Processing Record 17 of Set 10 | buchanan
# Processing Record 18 of Set 10 | fort-shevchenko
# Processing Record 19 of Set 10 | tucupita
# Processing Record 20 of Set 10 | malanje
# Processing Record 21 of Set 10 | matara
# Processing Record 22 of Set 10 | port shepstone
# Processing Record 23 of Set 10 | goundi
# Processing Record 24 of Set 10 | barawe
# City not found. Skipping...
# Processing Record 25 of Set 10 | fairbanks
# Processing Record 26 of Set 10 | tucurui
# Processing Record 27 of Set 10 | ambositra
# Processing Record 28 of Set 10 | vezirkopru
# Processing Record 29 of Set 10 | itarema
# Processing Record 30 of Set 10 | san cristobal
# Processing Record 31 of Set 10 | suntar
# Processing Record 32 of Set 10 | paragominas
# Processing Record 33 of Set 10 | centralia
# Processing Record 34 of Set 10 | mataram
# Processing Record 35 of Set 10 | waipawa
# Processing Record 36 of Set 10 | enumclaw
# Processing Record 37 of Set 10 | barroquinha
# Processing Record 38 of Set 10 | ojinaga
# Processing Record 39 of Set 10 | malakal
# Processing Record 40 of Set 10 | caravelas
# Processing Record 41 of Set 10 | inhambane
# Processing Record 42 of Set 10 | eyl
# Processing Record 43 of Set 10 | hudiksvall
# Processing Record 44 of Set 10 | presidente epitacio
# Processing Record 45 of Set 10 | bowen
# Processing Record 46 of Set 10 | gurskoye
# City not found. Skipping...
# Processing Record 47 of Set 10 | maragogi
# Processing Record 48 of Set 10 | quatre cocos
# Processing Record 49 of Set 10 | vestmannaeyjar
# Processing Record 0 of Set 11 | kasane
# Processing Record 1 of Set 11 | borova
# Processing Record 2 of Set 11 | luangwa
# Processing Record 3 of Set 11 | maanshan
# Processing Record 4 of Set 11 | sainte-maxime
# Processing Record 5 of Set 11 | ulladulla
# Processing Record 6 of Set 11 | bafq
# Processing Record 7 of Set 11 | sao joao da barra
# Processing Record 8 of Set 11 | sena madureira
# Processing Record 9 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 10 of Set 11 | adrar
# Processing Record 11 of Set 11 | laguna
# Processing Record 12 of Set 11 | chuy
# Processing Record 13 of Set 11 | severomuysk
# Processing Record 14 of Set 11 | havelock
# Processing Record 15 of Set 11 | chatham
# Processing Record 16 of Set 11 | port keats
# Processing Record 17 of Set 11 | beboto
# Processing Record 18 of Set 11 | gawler
# Processing Record 19 of Set 11 | bilma
# Processing Record 20 of Set 11 | teknaf
# Processing Record 21 of Set 11 | weligama
# Processing Record 22 of Set 11 | jumla
# Processing Record 23 of Set 11 | burica
# City not found. Skipping...
# Processing Record 24 of Set 11 | beyneu
# Processing Record 25 of Set 11 | tessalit
# Processing Record 26 of Set 11 | kiruna
# Processing Record 27 of Set 11 | swan hill
# Processing Record 28 of Set 11 | mayumba
# Processing Record 29 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 30 of Set 11 | noshiro
# Processing Record 31 of Set 11 | solnechnyy
# Processing Record 32 of Set 11 | kieta
# Processing Record 33 of Set 11 | maxixe
# Processing Record 34 of Set 11 | lubu
# Processing Record 35 of Set 11 | nome
# Processing Record 36 of Set 11 | atambua
# Processing Record 37 of Set 11 | launceston
# Processing Record 38 of Set 11 | tubruq
# City not found. Skipping...
# Processing Record 39 of Set 11 | ginda
# Processing Record 40 of Set 11 | merauke
# Processing Record 41 of Set 11 | ust-kan
# Processing Record 42 of Set 11 | taunggyi
# Processing Record 43 of Set 11 | seymchan
# Processing Record 44 of Set 11 | padang
# Processing Record 45 of Set 11 | gusino
# Processing Record 46 of Set 11 | honiara
# Processing Record 47 of Set 11 | cajati
# Processing Record 48 of Set 11 | fort myers
# Processing Record 49 of Set 11 | northam
# Processing Record 0 of Set 12 | micheweni
# Processing Record 1 of Set 12 | nueva loja
# Processing Record 2 of Set 12 | zhaotong
# Processing Record 3 of Set 12 | cayenne
# Processing Record 4 of Set 12 | chicama
# Processing Record 5 of Set 12 | pyay
# Processing Record 6 of Set 12 | esperance
# Processing Record 7 of Set 12 | high rock
# Processing Record 8 of Set 12 | ocara
# Processing Record 9 of Set 12 | kudat
# Processing Record 10 of Set 12 | constitucion
# Processing Record 11 of Set 12 | alvdal
# Processing Record 12 of Set 12 | southgate
# Processing Record 13 of Set 12 | san luis
# Processing Record 14 of Set 12 | george town
# Processing Record 15 of Set 12 | armizonskoye
# Processing Record 16 of Set 12 | jalingo
# Processing Record 17 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 18 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 19 of Set 12 | vao
# Processing Record 20 of Set 12 | tortoli
# Processing Record 21 of Set 12 | karasjok
# Processing Record 22 of Set 12 | saint-augustin
# Processing Record 23 of Set 12 | kupang
# Processing Record 24 of Set 12 | narasannapeta
# Processing Record 25 of Set 12 | fortuna
# Processing Record 26 of Set 12 | destin
# Processing Record 27 of Set 12 | requena
# Processing Record 28 of Set 12 | general roca
# Processing Record 29 of Set 12 | ilulissat
# Processing Record 30 of Set 12 | amurzet
# Processing Record 31 of Set 12 | loding
# Processing Record 32 of Set 12 | chunoyar
# Processing Record 33 of Set 12 | seoul
# Processing Record 34 of Set 12 | ballymena
# Processing Record 35 of Set 12 | barra do garcas
# Processing Record 36 of Set 12 | namanyere
# Processing Record 37 of Set 12 | tishchenskoye
# Processing Record 38 of Set 12 | sassandra
# Processing Record 39 of Set 12 | port hardy
# Processing Record 40 of Set 12 | klang
# Processing Record 41 of Set 12 | tuggurt
# City not found. Skipping...
# Processing Record 42 of Set 12 | iquique
# Processing Record 43 of Set 12 | ha tinh
# Processing Record 44 of Set 12 | upington
# Processing Record 45 of Set 12 | boundiali
# Processing Record 46 of Set 12 | sacama
# Processing Record 47 of Set 12 | sharlyk
# Processing Record 48 of Set 12 | tehachapi
# Processing Record 49 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 0 of Set 13 | sibolga
# Processing Record 1 of Set 13 | sorland
# Processing Record 2 of Set 13 | saryshagan
# City not found. Skipping...
# Processing Record 3 of Set 13 | benghazi
# Processing Record 4 of Set 13 | jabinyanah
# Processing Record 5 of Set 13 | tocopilla
# Processing Record 6 of Set 13 | iracoubo
# Processing Record 7 of Set 13 | bondo
# Processing Record 8 of Set 13 | hervey bay
# Processing Record 9 of Set 13 | manjacaze
# Processing Record 10 of Set 13 | salinopolis
# Processing Record 11 of Set 13 | dalby
# Processing Record 12 of Set 13 | wagar
# Processing Record 13 of Set 13 | macheng
# Processing Record 14 of Set 13 | pueblo
# Processing Record 15 of Set 13 | karratha
# Processing Record 16 of Set 13 | winnemucca
# Processing Record 17 of Set 13 | quesnel
# Processing Record 18 of Set 13 | kemijarvi
# Processing Record 19 of Set 13 | stara vyzhivka
# Processing Record 20 of Set 13 | irece
# Processing Record 21 of Set 13 | araripina
# Processing Record 22 of Set 13 | soc trang
# Processing Record 23 of Set 13 | nesterov
# Processing Record 24 of Set 13 | chake chake
# Processing Record 25 of Set 13 | mjolby
# Processing Record 26 of Set 13 | beroroha
# Processing Record 27 of Set 13 | les cayes
# Processing Record 28 of Set 13 | alice town
# Processing Record 29 of Set 13 | tazovskiy
# Processing Record 30 of Set 13 | corvallis
# Processing Record 31 of Set 13 | coos bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          579
# Lat           579
# Lng           579
# Max Temp      579
# Humidity      579
# Cloudiness    579
# Wind Speed    579
# Country       579
# Date          579
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   tuktoyaktuk  69.4541 -133.0374    245.75        99         100
# 1       husavik  66.0449  -17.3389    272.85        76          91
# 2          biak  -0.9131  122.8766    301.39        66         100
# 3  puerto ayora  -0.7393  -90.3518    296.79        97          39
# 4    mandalgovi  45.7625  106.2708    251.91        74         100
#
#    Wind Speed Country        Date
# 0        1.45      CA  1674367139
# 1        6.22      IS  1674367139
# 2        0.70      ID  1674367139
# 3        1.82      EC  1674367139
# 4        9.40      MN  1674367139

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0         tuktoyaktuk  69.4541 -133.0374    245.75        99         100
# 1             husavik  66.0449  -17.3389    272.85        76          91
# 2                biak  -0.9131  122.8766    301.39        66         100
# 3        puerto ayora  -0.7393  -90.3518    296.79        97          39
# 4          mandalgovi  45.7625  106.2708    251.91        74         100
#
#          Wind Speed Country        Date
# City_ID
# 0              1.45      CA  1674367139
# 1              6.22      IS  1674367139
# 2              0.70      ID  1674367139
# 3              1.82      EC  1674367139
# 4              9.40      MN  1674367139

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
city_data_df.dtypes
# Out:
# City           object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Country        object
# Date            int64
# dtype: object

# %%
# Build scatter plot for latitude vs. temperature

plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black", linewidths=1, marker="o", s=10, alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity(%s)" % time.strftime("%x"))
plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black", linewidths=1, marker="o", alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
def plot_linear_regression(x_values, y_values, x_label, y_label, text_coordinates):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel(x_label)
    plt.ylabel(y_label)

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        tuktoyaktuk  69.4541 -133.0374    245.75        99         100
# 1            husavik  66.0449  -17.3389    272.85        76          91
# 4         mandalgovi  45.7625  106.2708    251.91        74         100
# 6          belyy yar  53.6039   91.3903    242.09        83          20
# 7         sao filipe  14.8961  -24.4956    294.43        64          16
#
#          Wind Speed Country        Date
# City_ID
# 0              1.45      CA  1674367139
# 1              6.22      IS  1674367139
# 4              9.40      MN  1674367139
# 6              0.00      RU  1674367140
# 7              5.16      CV  1674367140

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2                 biak  -0.9131  122.8766    301.39        66         100
# 3         puerto ayora  -0.7393  -90.3518    296.79        97          39
# 5               sorong  -0.8833  131.2500    301.18        71          97
# 12       mar del plata -38.0023  -57.5575    293.68        81           0
# 13            hermanus -34.4187   19.2345    291.93        80          93
#
#          Wind Speed Country        Date
# City_ID
# 2              0.70      ID  1674367139
# 3              1.82      EC  1674367139
# 5              2.90      ID  1674367140
# 12             4.12      AR  1674367141
# 13             2.43      ZA  1674367142

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) + " R-value: " + str(round(rvalue,2))
plt.figure(figsize=(8,6))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title("Temperature VS. Latitude in Northern Hemisphere")
plt.legend(['Linear Regression', 'City'])
plt.show()

print(rvalue)
# Out:
# -0.8580785901058181

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) + " R-value: " + str(round(rvalue,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.title("Temperature VS. Latitude in Southern Hemisphere")
plt.legend(['Linear Regression'])
plt.show()
print(rvalue)
# Out:
# 0.41964070989412566

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) + " R-value: " + str(round(rvalue,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Humidity vs. Latitude Linear Regression Plot on Northern Hemisphere")
plt.show()
print(rvalue)
# Out:
# 0.4334475971380313

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) + " R-value: " + str(round(rvalue,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title("Humidity vs. Latitude Linear Regression Plot on Southern Hemisphere")
plt.show()
print(rvalue)
# Out:
# 0.2800475679789526

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) + " R-value: " + str(round(rvalue,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Cloudiness vs. Latitude Linear Regression Plot on Northern Hemisphere")
plt.show()
print(rvalue)
# Out:
# 0.20681277134365494

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) + " R-value: " + str(round(rvalue,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,50),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title("Cloudiness vs. Latitude Linear Regression Plot on Southern Hemisphere")
plt.show()
print(rvalue)
# Out:
# 0.33326143743359343

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) + " R-value: " + str(round(rvalue,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("Wind Speed vs. Latitude Linear Regression Plot on Northern Hemisphere")
plt.show()

print(rvalue)
# Out:
# 0.1418735853549062

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2)) + " R-value: " + str(round(rvalue,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-30,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title("Wind Speed vs. Latitude Linear Regression Plot on Southern Hemisphere")
plt.show()

print(rvalue)
# Out:
# -0.25882400325074106

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# From the above linear regression plots, we can conclude the following:
# 1. There is a linear relationship between temperature and latitude, where temperature decreases as latitude increases in the northern hemisphere.
# 2. Temperature increases as latitude increases in the southern hemisphere.
# 3. There is no clear linear relationship between wind speed and latitude.
